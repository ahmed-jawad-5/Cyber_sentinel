# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("results.csv", dtype={"dur": float})
df.head()
# Out:
#         dur  sbytes  dbytes         Sload   swin       stcpb     smeansz  \
# 0  0.000000      74       0  7.400000e+07  64240  3277084870   74.000000
# 1  0.000000      74       0  7.400000e+07  64240   668193395   74.000000
# 2  0.298511     643       0  2.154024e+03  12898  2885542180  128.600000
# 3  0.201594     206       0  1.021858e+03  23213  2668396847   68.666667
# 4  0.731710     642       0  8.773971e+02  12898  2498658756  128.400000
#
#        Sjit  Djit         Stime   Sintpkt  tcprtt  synack  ct_srv_src  \
# 0  0.000000   0.0  1.765293e+09  0.000000     0.0     0.0           2
# 1  0.000000   0.0  1.765293e+09  0.000000     0.0     0.0           2
# 2  0.081565   0.0  1.765293e+09  0.074628     0.0     0.0           2
# 3  0.094608   0.0  1.765293e+09  0.100797     0.0     0.0           2
# 4  0.183120   0.0  1.765293e+09  0.182927     0.0     0.0           2
#
#    ct_srv_dst  ct_dst_ltm  ct_src_ ltm  ct_dst_src_ltm  reconstruction_error  \
# ...

# %%
df.dtypes
# Out:
# dur                     float64
# sbytes                    int64
# dbytes                    int64
# Sload                   float64
# swin                      int64
# stcpb                     int64
# smeansz                 float64
# Sjit                    float64
# Djit                    float64
# Stime                   float64
# Sintpkt                 float64
# tcprtt                  float64
# synack                  float64
# ct_srv_src                int64
# ct_srv_dst                int64
# ct_dst_ltm                int64
# ct_src_ ltm               int64
# ct_dst_src_ltm            int64
# reconstruction_error    float64
# label                    object
# dtype: object
